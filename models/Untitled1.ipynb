# %%
# connection bdd
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
# connexion à la bdd avec mysql.connector
host="localhost"
port=3306
username="root"
password="selmane2003"
dbname="jobfinder_dbdev"

# %%
connection_string = f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{dbname}"
engine = create_engine(connection_string)

# %%
# import df 
df = pd.read_csv('../data/silver_data.csv')
df.head()
# Out:
#                                                 jobs  \
# 0               Data Engineer sénior (F/H) CDI (H/F)
# 1             Data Consultant Stratégie Sénior (H/F)
# 2  Chef de projets Performance Durable/Energie/Da...
# 3                                 Ingénieur Data H/F
# 4     Data Engineer pour la Qualité Totale H/F (H/F)
#
#                                          description                      loc  \
# 0  En tant que Data Engineer chez Quantmetry, vou...            75 - PARIS 08
# 1  Nous recrutons des personnes avec une appétenc...            75 - PARIS 08
# 2  Intégré(e) au sein de la Direction Performance...  92 - ASNIERES SUR SEINE
# 3  Vos missions\nAu sein de projets Agile Scrum, ...           66 - PERPIGNAN
# 4  Vous êtes Rattaché(e) au Responsable de l'équi...            92 - ST CLOUD
#
#                      datePosted               workhours             salary  \
# 0  Actualisé le 12 juillet 2023  38H Travail en journée  40000.0 - 50000.0
# ...

# %%
table_name='raw_table'
df.to_sql(name=table_name, con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/netflix-recommendation/lib/python3.8/site-packages/mysql/connector/connection_cext.py:302, in CMySQLConnection._open_connection(self)
#     301 try:
# --> 302     self._cmysql.connect(**cnx_kwargs)
#     303     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (111)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/netflix-recommendation/lib/python3.8/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# ...
