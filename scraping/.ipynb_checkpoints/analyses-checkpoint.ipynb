# %%
# import des librairies
import numpy as np
import pandas as pd
import plotly as px

# preprocessing 
import re

# %%
# import des données
df = pd.read_csv("../data/silver/silver_data.csv")
df.head()
# Out:
#                                                 jobs  \
# 0               Data Engineer sénior (F/H) CDI (H/F)
# 1             Data Consultant Stratégie Sénior (H/F)
# 2  Chef de projets Performance Durable/Energie/Da...
# 3                                 Ingénieur Data H/F
# 4     Data Engineer pour la Qualité Totale H/F (H/F)
#
#                                          description                      loc  \
# 0  En tant que Data Engineer chez Quantmetry, vou...            75 - PARIS 08
# 1  Nous recrutons des personnes avec une appétenc...            75 - PARIS 08
# 2  Intégré(e) au sein de la Direction Performance...  92 - ASNIERES SUR SEINE
# 3  Vos missions\nAu sein de projets Agile Scrum, ...           66 - PERPIGNAN
# 4  Vous êtes Rattaché(e) au Responsable de l'équi...            92 - ST CLOUD
#
#                      datePosted               workhours             salary  \
# 0  Actualisé le 12 juillet 2023  38H Travail en journée  40000.0 - 50000.0
# 1  Actualisé le 12 juillet 2023  35H Travail en journée    3100.0 - 5000.0
# 2  Actualisé le 13 juillet 2023  35H Travail en journée                NaN
# 3  Actualisé le 19 juillet 2023  35H Travail en journée                NaN
# 4  Actualisé le 19 juillet 2023  35H Travail en journée  38000.0 - 70000.0
#
#                   contract_type experience diploma  \
# 0  Contrat à durée indéterminée      5 ans     NaN
# 1  Contrat à durée indéterminée      5 ans     NaN
# 2  Contrat à durée indéterminée      3 ans     NaN
# 3  Contrat à durée indéterminée      5 ans     NaN
# 4  Contrat à durée indéterminée      5 ans     NaN
#
#                                               skills    qualifications  \
# 0  concevoir et gérer un projet, concevoir un log...             Cadre
# 1  analyser les résultats d'un projet, décliner l...             Cadre
# 2  contrôler et faire appliquer le respect de dis...  Employé qualifié
# 3  concevoir et gérer un projet, concevoir un log...             Cadre
# 4  application web, déterminer des mesures correc...             Cadre
#
#                                             industry  \
# 0  Conseil pour les affaires et autres conseils d...
# 1  Conseil pour les affaires et autres conseils d...
# 2                       Activités des sièges sociaux
# 3  Autres intermédiaires du commerce en denrées, ...
# 4                       Activités des sièges sociaux
#
#                                     company  \
# 0                                QUANTMETRY
# 1                                QUANTMETRY
# 2                                    NEXITY
# 3  SOCIETE DE DISTRIBUTION DE PRODUITS MARA
# 4                         DASSAULT AVIATION
#
#                                                 size  \
# 0                                 100 à 199 salariés
# 1                                 100 à 199 salariés
# 2                                 250 à 499 salariés
# 3                                 100 à 199 salariés
# 4  Non employeur (pas de salarié au cours de l'an...
#
#                                  company_description         tools ID_dep  \
# 0  Pure player en Data et Intelligence Artificiel...           NaN     75
# 1  Pure player en Data et Intelligence Artificiel...           NaN     75
# 2  Nexity est aujourd hui leader sur les différen...       tableau     92
# 3  Azura, est un groupe familial, en forte croiss...  tableau, sas     66
# 4                                  Dassault Aviation           NaN     92
#
#                 ville        date
# 0            PARIS 08  2023/07/12
# 1            PARIS 08  2023/07/12
# 2  ASNIERES SUR SEINE  2023/07/13
# 3           PERPIGNAN  2023/07/19
# 4            ST CLOUD  2023/07/19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3299 entries, 0 to 3298
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   jobs                 3299 non-null   object
#  1   description          3299 non-null   object
#  2   loc                  999 non-null    object
#  3   datePosted           999 non-null    object
#  4   workhours            604 non-null    object
#  5   salary               487 non-null    object
#  6   contract_type        3299 non-null   object
#  7   experience           3299 non-null   object
#  8   diploma              116 non-null    object
#  9   skills               280 non-null    object
#  10  qualifications       1545 non-null   object
#  11  industry             1633 non-null   object
#  12  company              1743 non-null   object
#  13  size                 2171 non-null   object
#  14  company_description  1817 non-null   object
#  15  tools                1673 non-null   object
#  16  ID_dep               3299 non-null   object
#  17  ville                2936 non-null   object
#  18  date                 3299 non-null   object
# dtypes: object(19)
# memory usage: 489.8+ KB

# %% [markdown]
# ## Preprocessing

# %%
def add_contract_type(df):
    df["contract_type"] = df["contract_type"].str.replace('contrat à durée indéterminée', 'CDI', flags=re.IGNORECASE)
    df["contract_type"] = df["contract_type"].str.replace('contrat à durée déterminée', 'CDD', flags=re.IGNORECASE)

    def extract_duration(row):
        match = re.search(r'(\d+\s*\D+)', row['contract_type'])
        if match:
            return match.group(1).strip()
        else:
            if 'CDI' in row['contract_type']:
                return 'Indéterminé'
            else:
                return 'non renseignée'

    df['contract_type_duration'] = df.apply(extract_duration, axis=1)

    def get_contract_label(contract):
        if re.search(r'CDI', contract, re.IGNORECASE):
            return 'CDI'
        elif re.search(r'CDD', contract, re.IGNORECASE):
            return 'CDD'
        elif re.search(r'intérim|intérimaire', contract, re.IGNORECASE):
            return 'Mission intérimaire'
        elif re.search(r'Franchise', contract, re.IGNORECASE):
            return 'Franchise'
        elif re.search(r'profession libérale', contract, re.IGNORECASE):
            return 'Profession libérale'
        return None

    df['contract_type_label'] = df['contract_type'].apply(get_contract_label)
    
    def get_contract_number(contract):
        if 'CDI' in contract:
            return 1
        elif 'CDD' in contract:
            return 2
        elif 'Mission intérimaire' in contract:
            return 3
        elif 'Franchise' in contract:
            return 5
        elif 'Profession libérale' in contract:
            return 6
        return None

    df['contract_type_number'] = df['contract_type_label'].apply(get_contract_number)

    return df

# %%
df = add_contract_type(df)

# %%
df.head(2)
# Out:
#                                      jobs  \
# 0    Data Engineer sénior (F/H) CDI (H/F)
# 1  Data Consultant Stratégie Sénior (H/F)
#
#                                          description            loc  \
# 0  En tant que Data Engineer chez Quantmetry, vou...  75 - PARIS 08
# 1  Nous recrutons des personnes avec une appétenc...  75 - PARIS 08
#
#                      datePosted               workhours             salary  \
# 0  Actualisé le 12 juillet 2023  38H Travail en journée  40000.0 - 50000.0
# 1  Actualisé le 12 juillet 2023  35H Travail en journée    3100.0 - 5000.0
#
#   contract_type experience diploma  \
# 0           CDI      5 ans     NaN
# 1           CDI      5 ans     NaN
#
#                                               skills  ...     company  \
# 0  concevoir et gérer un projet, concevoir un log...  ...  QUANTMETRY
# 1  analyser les résultats d'un projet, décliner l...  ...  QUANTMETRY
#
#                  size                                company_description  \
# 0  100 à 199 salariés  Pure player en Data et Intelligence Artificiel...
# 1  100 à 199 salariés  Pure player en Data et Intelligence Artificiel...
#
#   tools ID_dep     ville        date contract_type_duration  \
# 0   NaN     75  PARIS 08  2023/07/12                   None
# 1   NaN     75  PARIS 08  2023/07/12                   None
#
#   contract_type_label contract_type_number
# 0                 CDI                    1
# 1                 CDI                    1
#
# [2 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# jobs                         0
# description                  0
# loc                       2300
# datePosted                2300
# workhours                 2695
# salary                    2812
# contract_type                0
# experience                   0
# diploma                   3183
# skills                    3019
# qualifications            1754
# industry                  1666
# company                   1556
# size                      1128
# company_description       1482
# tools                     1626
# ID_dep                       0
# ville                      363
# date                         0
# contract_type_duration    2932
# contract_type_label          0
# contract_type_number         0
# dtype: int64

# %%
df["contract_type_label"].value_counts()
# Out:
# contract_type_label
# CDI                    2116
# Profession libérale     605
# CDD                     317
# Franchise               211
# Mission intérimaire      50
# Name: count, dtype: int64

# %%
df["contract_type_duration"].count()
# Out:
# 367

# %%
Nan_df = df.loc[df["contract_type_duration"].isnull()]
Nan_df
# Out:
#                                                    jobs  \
# 0                  Data Engineer sénior (F/H) CDI (H/F)
# 1                Data Consultant Stratégie Sénior (H/F)
# 2     Chef de projets Performance Durable/Energie/Da...
# 3                                    Ingénieur Data H/F
# 4        Data Engineer pour la Qualité Totale H/F (H/F)
# ...                                                 ...
# 3294          Data Engineer - Système, réseaux, données
# 3295                                       Data manager
# 3296                Développeur / Développeuse Big Data
# 3297                Développeur / Développeuse Big Data
# 3298                Développeur / Développeuse Big Data
#
#                                             description  \
# 0     En tant que Data Engineer chez Quantmetry, vou...
# 1     Nous recrutons des personnes avec une appétenc...
# 2     Intégré(e) au sein de la Direction Performance...
# 3     Vos missions\nAu sein de projets Agile Scrum, ...
# 4     Vous êtes Rattaché(e) au Responsable de l'équi...
# ...                                                 ...
# 3294  Descriptif du poste:\n\n\nAu sein d'une équipe...
# 3295  Espace-Freelance, réseau de consultants indépe...
# 3296  Nous recherchons pour l'un de nos clients un(e...
# 3297  Contexte / Objectifs : \nAu sein de la platefo...
# 3298  Ton quotidien chez Komeet sera rythmé par :\n\...
#
#                           loc                    datePosted  \
# 0               75 - PARIS 08  Actualisé le 12 juillet 2023
# 1               75 - PARIS 08  Actualisé le 12 juillet 2023
# 2     92 - ASNIERES SUR SEINE  Actualisé le 13 juillet 2023
# 3              66 - PERPIGNAN  Actualisé le 19 juillet 2023
# 4               92 - ST CLOUD  Actualisé le 19 juillet 2023
# ...                       ...                           ...
# 3294                      NaN                           NaN
# 3295                      NaN                           NaN
# 3296                      NaN                           NaN
# 3297                      NaN                           NaN
# 3298                      NaN                           NaN
#
#                    workhours             salary        contract_type  \
# 0     38H Travail en journée  40000.0 - 50000.0                  CDI
# 1     35H Travail en journée    3100.0 - 5000.0                  CDI
# 2     35H Travail en journée                NaN                  CDI
# 3     35H Travail en journée                NaN                  CDI
# 4     35H Travail en journée  38000.0 - 70000.0                  CDI
# ...                      ...                ...                  ...
# 3294                     NaN                NaN                  CDI
# 3295                     NaN                NaN  Profession libérale
# 3296                     NaN                NaN  Profession libérale
# 3297                     NaN                NaN  Profession libérale
# 3298                     NaN  36000.0 - 75000.0                  CDI
#
#                         experience diploma  \
# 0                            5 ans     NaN
# 1                            5 ans     NaN
# 2                            3 ans     NaN
# 3                            5 ans     NaN
# 4                            5 ans     NaN
# ...                            ...     ...
# 3294              Débutant accepté     NaN
# 3295  Expérience exigée de 2 An(s)     NaN
# 3296  Expérience exigée de 5 An(s)     NaN
# 3297  Expérience exigée de 5 An(s)     NaN
# 3298             Expérience exigée     NaN
#
#                                                  skills  ...  \
# 0     concevoir et gérer un projet, concevoir un log...  ...
# 1     analyser les résultats d'un projet, décliner l...  ...
# 2     contrôler et faire appliquer le respect de dis...  ...
# 3     concevoir et gérer un projet, concevoir un log...  ...
# 4     application web, déterminer des mesures correc...  ...
# ...                                                 ...  ...
# 3294                                                NaN  ...
# 3295                                                NaN  ...
# 3296                                                NaN  ...
# 3297                                                NaN  ...
# 3298                                                NaN  ...
#
#                                        company  \
# 0                                   QUANTMETRY
# 1                                   QUANTMETRY
# 2                                       NEXITY
# 3     SOCIETE DE DISTRIBUTION DE PRODUITS MARA
# 4                            DASSAULT AVIATION
# ...                                        ...
# 3294         MICHAEL PAGE INTERNATIONAL FRANCE
# 3295                          Espace Freelance
# 3296                             ALLEGIS GROUP
# 3297                               HN SERVICES
# 3298                       KOMEET TECHNOLOGIES
#
#                                                    size  \
# 0                                    100 à 199 salariés
# 1                                    100 à 199 salariés
# 2                                    250 à 499 salariés
# 3                                    100 à 199 salariés
# 4     Non employeur (pas de salarié au cours de l'an...
# ...                                                 ...
# 3294  Notre client est un Groupe régional, fort de s...
# 3295                                                NaN
# 3296                                                NaN
# 3297                                                NaN
# 3298                                                NaN
#
#                                     company_description  \
# 0     Pure player en Data et Intelligence Artificiel...
# 1     Pure player en Data et Intelligence Artificiel...
# 2     Nexity est aujourd hui leader sur les différen...
# 3     Azura, est un groupe familial, en forte croiss...
# 4                                     Dassault Aviation
# ...                                                 ...
# 3294  Notre client est un Groupe régional, fort de s...
# 3295                                                NaN
# 3296                                                NaN
# 3297                                                NaN
# 3298                                                NaN
#
#                                                   tools ID_dep  \
# 0                                                   NaN     75
# 1                                                   NaN     75
# 2                                               tableau     92
# 3                                          tableau, sas     66
# 4                                                   NaN     92
# ...                                                 ...    ...
# 3294                                                NaN     44
# 3295                                                NaN     59
# 3296  gitlab, docker, kubernetes, grafana, prometheu...     75
# 3297                              power bi, informatica     75
# 3298                                                NaN     75
#
#                    ville        date contract_type_duration  \
# 0               PARIS 08  2023/07/12                   None
# 1               PARIS 08  2023/07/12                   None
# 2     ASNIERES SUR SEINE  2023/07/13                   None
# 3              PERPIGNAN  2023/07/19                   None
# 4               ST CLOUD  2023/07/19                   None
# ...                  ...         ...                    ...
# 3294              NANTES  2023/08/31                   None
# 3295   VILLENEUVE D ASCQ  2023/08/31                   None
# 3296            PARIS 01  2023/08/31                   None
# 3297            PARIS 01  2023/08/31                   None
# 3298            PARIS 01  2023/08/31                   None
#
#       contract_type_label contract_type_number
# 0                     CDI                    1
# 1                     CDI                    1
# 2                     CDI                    1
# 3                     CDI                    1
# 4                     CDI                    1
# ...                   ...                  ...
# 3294                  CDI                    1
# 3295  Profession libérale                    6
# 3296  Profession libérale                    6
# 3297  Profession libérale                    6
# 3298                  CDI                    1
#
# [2932 rows x 22 columns]

# %%
df["contract_type_number"].unique()
# Out:
# array([1, 3, 2, 5, 6])

# %%
df["contract_type"].unique()
# Out:
# array(['CDI', 'Mission intérimaire - 1 Mois', 'CDD - 4 Mois',
#        'CDD - 24 Mois', 'CDD - 10 Mois', 'CDD - 1 Mois', 'CDD - 26 Mois',
#        'CDD - 12 Mois', 'CDD - 6 Mois', 'Mission intérimaire - 5 Mois',
#        'Mission intérimaire - 6 Mois', 'CDD - 0 Mois', 'Franchise',
#        'CDD - 36 Mois', 'Mission intérimaire - 18 Mois', 'CDD - 3 Mois',
#        'Mission intérimaire - 12 Mois', 'Profession libérale',
#        'Mission intérimaire - 3 Mois', 'CDD - 25 Mois',
#        'Mission intérimaire - 11 Mois', 'CDD - 14 Mois', 'CDD - 8 Mois',
#        'CDD - 2 Mois', 'CDD - 5 Mois', 'CDD - 7 Mois', 'CDD - 9 Mois',
#        'Mission intérimaire - 2 Mois', 'CDD - 18 Mois', 'CDD - 30 Mois',
#        'CDD - 16 Mois', 'Mission intérimaire - 24 Mois'], dtype=object)

# %% [markdown]
# ## Visualisations
